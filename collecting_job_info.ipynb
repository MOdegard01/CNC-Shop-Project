# %%
from datetime import datetime
import pandas as pd

job = int(input("Enter Job Number: "))
part = int(input("Enter Part Number: "))
material = str(input("Aluminum or Steel? "))
due_date = datetime.strptime(input("Enter Due Date (yyyy-mm-dd): "), "%Y-%m-%d")
ops = int(input("How many operations does this job have? "))

ops_info = {}

for x in range(ops):
    y = x + 1
    dept = int(input(f"Which department runs op {y}? "))
    setup_time = float(input("Enter setup time: "))
    run_time = float(input("Enter run time: "))
    ops_info[y] = {"Op Seq: ": y, "Department: ": dept, "Setup Time: ": setup_time, "Run Time: ": run_time}
    x += 1

job_info = {"Job: ": job, "Part Number: ": part, "Material: ": material, "Due: ": due_date, "Job Details: ": ops_info}

schedule = pd.DataFrame(columns = ["Job", "Part Number", "Material", "Due Date", "Operation Sequence", "Department", "Setup Time", "Run Time"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 4
#       1 from datetime import datetime
#       2 import pandas as pd
# ----> 4 job = int(input("Enter Job Number: "))
#       5 part = int(input("Enter Part Number: "))
#       6 material = str(input("Aluminum or Steel? "))
#
# ValueError: invalid literal for int() with base 10: ''
